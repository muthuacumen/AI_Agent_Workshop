# %% [markdown]
# ## Setup: Getting Your Google Gemini API Key
# Before we begin building our AI Agents, you need your own access key to the Gemini API. We are using individual keys to ensure everyone has dedicated bandwidth and won't hit rate limits during the workshop.
#
# **Instructions:**
# 1. Go to **[Google AI Studio](https://aistudio.google.com)**.
# 2. Sign in with your university or standard Google account.
# 3. Click **Get API Key** in the left-hand navigation menu.
# 4. Click **Create API key** and select a new or existing project.
# 5. Copy the generated key. (Keep this secret!)
#
# *Note: Ensure you have activated your Miniconda or venv workshop environment before running the installation cell below.*
#
# Run the cell below to securely input your key. The `getpass` library will create a hidden input box so your key is never saved in the notebook.

# %%
# !pip install -q google-genai

import os
import getpass
from google import genai

# Securely prompt for the API key
print("Please enter your Google Gemini API Key:")
os.environ["GEMINI_API_KEY"] = getpass.getpass()

# Initialize the client
client = genai.Client()
print("\nGemini client initialized successfully! You are ready to build.")
# Out:
# Please enter your Google Gemini API Key:
#
# Gemini client initialized successfully! You are ready to build.
