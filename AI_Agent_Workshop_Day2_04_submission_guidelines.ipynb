# %% [markdown]
# ## The Workshop - Submission guidelines

# %% [markdown]
# One team member must push the final notebook to GitHub and send the `.git` URL to the instructor before the end of class.

# %% [markdown]
# ## 🧠 Learning Objectives
# - explain the difference between a prompt-based AI application, a retrieval-augmented application, and an agentified AI system;
# - describe the core components of an AI agent architecture, including the model, tools, control loop, memory or context, and output schema;
# - use the Google Gemini stack to build an AI/ML application that combines large language models with tool calling and structured outputs;
# - design and implement a simple agent workflow that routes a user query through retrieval, tool execution, and answer synthesis;
# - model a real-world public-service problem as a machine learning and agent design challenge;
# - prepare and normalize municipal, regional, provincial, and federal service data into a form suitable for retrieval and downstream reasoning;
# - build a local curated retrieval layer using CSV and JSON data as the default grounding mechanism;
# - implement function-calling tools that help an assistant identify the responsible level of government and recommend next steps;
# - generate grounded, structured answers that include service ownership, rationale, and actionable guidance;
# - evaluate an agent-based AI application using a benchmark set, task-specific metrics, and error analysis;
# - identify common failure modes in agentified systems, including weak retrieval, hallucinated authorities, ambiguity handling, and overconfident predictions;
# - compare baseline and improved system variants to understand the impact of retrieval, tools, and agent design patterns;
# - apply reproducibility and experimentation practices to agent-based AI systems using DVC pipelines;
# - organize data preparation, evaluation, and reporting into a lightweight ML pipeline that supports repeatable experiments;
# - reflect on how modern agent architectures can be used to solve public-sector and civic-service problems responsibly and effectively.
#
# ## 🧩 Workshop Structure (90 Minutes)
# 1. **Instructor-led demo of Agents, Agent Workflows, Parameters, and Frameworks** *(20 min)* – Set up teams of 3 people. Read and understand the workshop, plus submission instructions. Seek assistance if needed.
# 2. **Team Jupyter Notebook Development** *(65 min)* – All challenges covered in days 1 and 2 (work as teams)
# 3. **Push to GitHub** *(5 min)* – Teams commit and push the one notebook. **Make sure to include your names so it is easy to identify the team that developed the code**.
# 4. **Instructor Review** - The instructor will go around, take notes, and provide coaching as needed, during the **Peer Review Round**
# 5. **Email Delivery** *(1 min)* – Each team send the instructor an email **with the *.git link** to the GitHub repo **(one email/team)**. Subject on the email is: CSCN8010 - AI Agent Workshop, Team #_____.
#
#
# ## 💻 Submission Checklist
# - ✅ `AI_Agent_Workflow.ipynb` with:
#   - Workshop code: Implementing Hyperparameters, Optimizers,and Forward/Backward Passes and DVC orchaestration.
#   - **Talking points**: Answers to all talking point questions **in your own words**.
#   - Markdown explanations for each major step
# the use case that makes use of the knowledge corpus.
# - ✅ `README.md` with:
#   - A summary of the work done, including roadblocks and possible missed outcomes.
#   - Team member names
# - ✅ GitHub Repo:
#   - Public repo named `AI_Agent_Workshop`
#   - This is a group effort, so **choose one member of the team** to publish the repo
#   - At least **one commit containing one meaningful talking point**
